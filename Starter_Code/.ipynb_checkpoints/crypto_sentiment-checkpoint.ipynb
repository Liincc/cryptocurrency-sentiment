# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
import warnings
from newsapi import NewsApiClient
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Lincoln\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(q='bitcoin', language='en')
bitcoin_headlines['articles'][1]
article = bitcoin_headlines['articles'][1]
article
# Out:
# {'source': {'id': 'the-verge', 'name': 'The Verge'},
#  'author': 'Mitchell Clark',
#  'title': 'The International Monetary Fund tells El Salvador it shouldn’t use Bitcoin as legal tender',
#  'description': 'The International Monetary Fund’s executive directors have recommended to El Salvador that it should narrow the scope of its Bitcoin law, making it so that the cryptocurrency is no longer legal tender in the country.',
#  'url': 'https://www.theverge.com/2022/1/25/22901374/el-salvador-bitcoin-international-monetary-fund-crypto',
#  'urlToImage': 'https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpbAVPi6j4xmC2Ug=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/13546110/acastro_181126_1777_bitcoin_0001.jpg',
#  'publishedAt': '2022-01-25T22:11:14Z',
# ...

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(q='ethereum', language='en')
ethereum_headlines['articles'][0]
# Out:
# {'source': {'id': 'the-verge', 'name': 'The Verge'},
#  'author': 'Corin Faife',
#  'title': 'Crypto.com admits over $30 million stolen by hackers',
#  'description': 'Cryptocurrency exchange Crypto.com has said that $15 million in ethereum and $18 million in bitcoin were stolen by hackers in a security breach',
#  'url': 'https://www.theverge.com/2022/1/20/22892958/crypto-com-exchange-hack-bitcoin-ethereum-security',
#  'urlToImage': 'https://cdn.vox-cdn.com/thumbor/mde_l3lUC4muDPEFG7LYrUz0O3g=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8921023/acastro_bitcoin_2.jpg',
#  'publishedAt': '2022-01-20T13:23:31Z',
#  'content': 'In a new blog post the company said that 4,836 ETH and 443 bitcoin were taken\r\nIllustration by Alex Castro / The Verge\r\nIn a blog post published in the early hours of Thursday morning, cryptocurrency… [+2004 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_df = pd.DataFrame.from_dict(bitcoin_headlines['articles'])
bitcoin_df.head(2)
# Out:
#                                      source          author  \
# 0    {'id': None, 'name': 'Lifehacker.com'}     Jeff Somers
# 1  {'id': 'the-verge', 'name': 'The Verge'}  Mitchell Clark
#
#                                                title  \
# 0               Is the Crypto Bubble Going to Burst?
# 1  The International Monetary Fund tells El Salva...
#
#                                          description  \
# 0  Even if you aren’t paying attention to Bitcoin...
# 1  The International Monetary Fund’s executive di...
#
#                                                  url  \
# 0  https://lifehacker.com/is-the-crypto-bubble-go...
# 1  https://www.theverge.com/2022/1/25/22901374/el...
#
#                                           urlToImage           publishedAt  \
# 0  https://i.kinja-img.com/gawker-media/image/upl...  2022-02-09T16:00:00Z
# 1  https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpb...  2022-01-25T22:11:14Z
#
#                                              content
# ...

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_df = pd.DataFrame.from_dict(ethereum_headlines['articles'])
ethereum_df.head(2)
# Out:
#                                      source       author  \
# 0  {'id': 'the-verge', 'name': 'The Verge'}  Corin Faife
# 1       {'id': None, 'name': 'Gizmodo.com'}   Matt Novak
#
#                                                title  \
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Hackers Launder $15 Million Stolen From Crypto...
#
#                                          description  \
# 0  Cryptocurrency exchange Crypto.com has said th...
# 1  Hackers who made off with roughly $15 million ...
#
#                                                  url  \
# 0  https://www.theverge.com/2022/1/20/22892958/cr...
# 1  https://gizmodo.com/hackers-launder-15-million...
#
#                                           urlToImage           publishedAt  \
# 0  https://cdn.vox-cdn.com/thumbor/mde_l3lUC4muDP...  2022-01-20T13:23:31Z
# 1  https://i.kinja-img.com/gawker-media/image/upl...  2022-01-19T12:00:00Z
#
#                                              content
# ...

# %%
# Describe the Bitcoin Sentiment
bitcoin_sentiments = []

for article in bitcoin_headlines['articles']:
    try:
        text = article['content']
        date = article['publishedAt'][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment['compound']
        pos = sentiment['pos']
        neu = sentiment['neu']
        neg = sentiment['neg']
        
        bitcoin_sentiments.append({
            'text': text,
            'date': date,
            'compound': compound,
            'positive': pos,
            'negative': neg,
            'neutral': neu
        })
    except AttributeError:
        pass
    
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Even if you arent paying attention to Bitcoin ...  2022-02-09    0.5859
# 1  El Salvador introduced Bitcoin as a legal tend...  2022-01-25    0.3182
# 2  Were officially building an open Bitcoin minin...  2022-01-14   -0.4404
# 3  Israeli national Tal Prihar pled guilty to rou...  2022-01-27   -0.3182
# 4  In a new blog post the company said that 4,836...  2022-01-20    0.0000
#
#    positive  negative  neutral
# 0     0.124     0.000    0.876
# 1     0.105     0.000    0.895
# 2     0.000     0.083    0.917
# 3     0.045     0.084    0.871
# 4     0.000     0.000    1.000

# %%
# Describe the Ethereum Sentiment
ethereum_sentiments = []

for article in ethereum_headlines['articles']:
    try:
        text = article['content']
        date = article['publishedAt'][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment['compound']
        pos = sentiment['pos']
        neu = sentiment['neu']
        neg = sentiment['neg']
        
        ethereum_sentiments.append({
            'text': text,
            'date': date,
            'compound': compound,
            'positive': pos,
            'negative': neg,
            'neutral': neu
        })
    except AttributeError:
        pass
    
ethereum_df = pd.DataFrame(ethereum_sentiments)

ethereum_df.head()
# Out:
#                                                 text        date  compound  \
# 0  In a new blog post the company said that 4,836...  2022-01-20    0.0000
# 1  Hackers who made off with roughly $15 million ...  2022-01-19    0.0000
# 2  On some level, the new mayor is simply employi...  2022-01-20    0.1779
# 3  Back in September\r\n, Robinhood announced pla...  2022-01-21    0.0772
# 4  If people who buy cryptocurrencies intended on...  2022-02-10   -0.2023
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.000     0.000    1.000
# 2     0.052     0.000    0.948
# 3     0.038     0.000    0.962
# 4     0.039     0.062    0.899

# %%
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.095105   0.053250   0.022100   0.924650
# std     0.297967   0.054394   0.045603   0.074845
# min    -0.680800   0.000000   0.000000   0.775000
# 25%     0.000000   0.000000   0.000000   0.889750
# 50%     0.000000   0.043500   0.000000   0.931500
# 75%     0.233900   0.090250   0.011750   1.000000
# max     0.680800   0.185000   0.174000   1.000000

# %%
bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.043300   0.061950   0.044700   0.893350
# std     0.458509   0.060617   0.053913   0.056841
# min    -0.709600   0.000000   0.000000   0.765000
# 25%    -0.426225   0.000000   0.000000   0.862500
# 50%     0.127550   0.054500   0.000000   0.910500
# 75%     0.366350   0.109750   0.088000   0.928250
# max     0.778300   0.185000   0.169000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import nltk
nltk.download('wordnet')
nltk.download('punkt')
import re
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lincoln\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lincoln\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()


# Create a list of stopwords

sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addon = {'said', 'mln'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)

    
    # Create a tokenized list of the words  # Convert the words to lowercase # Remove the stop words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    re_result = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
    
    return re_result

print(tokenizer(text))
# Out:
# ['version', 'article', 'wa', 'published', 'times', 'newsletter', 'metaverse', 'subscribe', 'weekly', 'guide', 'future', 'internetyou', 'find', 'past', 'issue', 'newsletter', 'herewhen', 'vita', 'char']

# %%
tokenized = []

for text in bitcoin_df['text']:
    tokenized_articles = tokenizer(text)
    
    tokenized.append({'tokens':tokenized_articles})
    
tokens_df = pd.DataFrame(tokenized)

#Adding tokens to the new tokens column in original df
bitcoin_df['tokens'] = tokens_df

bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Even if you arent paying attention to Bitcoin ...  2022-02-09    0.5859
# 1  El Salvador introduced Bitcoin as a legal tend...  2022-01-25    0.3182
# 2  Were officially building an open Bitcoin minin...  2022-01-14   -0.4404
# 3  Israeli national Tal Prihar pled guilty to rou...  2022-01-27   -0.3182
# 4  In a new blog post the company said that 4,836...  2022-01-20    0.0000
#
#    positive  negative  neutral  \
# 0     0.124     0.000    0.876
# 1     0.105     0.000    0.895
# 2     0.000     0.083    0.917
# 3     0.045     0.084    0.871
# 4     0.000     0.000    1.000
#
#                                               tokens
# 0  [even, arent, paying, attention, bitcoin, cryp...
# 1  [el, salvador, introduced, bitcoin, legal, ten...
# 2  [officially, building, open, bitcoin, mining, ...
# 3  [israeli, national, tal, prihar, pled, guilty,...
# 4  [new, blog, post, company, eth, bitcoin, taken...

# %%
bitcoin_df.dtypes
# Out:
# text         object
# date         object
# compound    float64
# positive    float64
# negative    float64
# neutral     float64
# tokens       object
# dtype: object

# %%
# Create a new tokens column for Bitcoin
updated_bitcoin_sentiments = []

for article in bitcoin_headlines['articles']:
    try:
        text = article['content']
        date = article['publishedAt'][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment['compound']
        pos = sentiment['pos']
        neu = sentiment['neu']
        neg = sentiment['neg']
        
        updated_bitcoin_sentiments.append({
            'text': text,
            'date': date,
            'compound': compound,
            'positive': pos,
            'negative': neg,
            'neutral': neu
        })
    except AttributeError:
        pass
    
updated_bitcoin_df = pd.DataFrame(updated_bitcoin_sentiments)

updated_bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Even if you arent paying attention to Bitcoin ...  2022-02-09    0.5859
# 1  El Salvador introduced Bitcoin as a legal tend...  2022-01-25    0.3182
# 2  Were officially building an open Bitcoin minin...  2022-01-14   -0.4404
# 3  Israeli national Tal Prihar pled guilty to rou...  2022-01-27   -0.3182
# 4  In a new blog post the company said that 4,836...  2022-01-20    0.0000
#
#    positive  negative  neutral
# 0     0.124     0.000    0.876
# 1     0.105     0.000    0.895
# 2     0.000     0.083    0.917
# 3     0.045     0.084    0.871
# 4     0.000     0.000    1.000

# %%
# Create a new tokens column for Ethereum
updated_ethereum_sentiments = []

for article in ethereum_headlines['articles']:
    try:
        text = article['content']
        date = article['publishedAt'][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment['compound']
        pos = sentiment['pos']
        neu = sentiment['neu']
        neg = sentiment['neg']
        
        updated_ethereum_sentiments.append({
            'text': text,
            'date': date,
            'compound': compound,
            'positive': pos,
            'negative': neg,
            'neutral': neu
        })
    except AttributeError:
        pass
    
updated_ethereum_df = pd.DataFrame(updated_ethereum_sentiments)

updated_ethereum_df.head()
# Out:
#                                                 text        date  compound  \
# 0  In a new blog post the company said that 4,836...  2022-01-20    0.0000
# 1  Hackers who made off with roughly $15 million ...  2022-01-19    0.0000
# 2  On some level, the new mayor is simply employi...  2022-01-20    0.1779
# 3  Back in September\r\n, Robinhood announced pla...  2022-01-21    0.0772
# 4  If people who buy cryptocurrencies intended on...  2022-02-10   -0.2023
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.000     0.000    1.000
# 2     0.052     0.000    0.948
# 3     0.038     0.000    0.962
# 4     0.039     0.062    0.899

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_grams = ngrams(tokenizer(bitcoin_df.text.str.cat()), 2)
Counter(btc_grams).most_common(20)
# Out:
# [(('bitcoin', 'mining'), 4),
#  (('alex', 'castro'), 3),
#  (('building', 'open'), 3),
#  (('open', 'bitcoin'), 3),
#  (('mining', 'system'), 3),
#  (('alongside', 'us'), 2),
#  (('illustration', 'alex'), 2),
#  (('international', 'monetary'), 2),
#  (('officially', 'building'), 2),
#  (('raedlegetty', 'imagesblock'), 2),
#  (('castro', 'vergein'), 2),
#  (('blog', 'post'), 2),
#  (('el', 'salvador'), 2),
#  (('even', 'arent'), 1),
#  (('arent', 'paying'), 1),
#  (('paying', 'attention'), 1),
#  (('attention', 'bitcoin'), 1),
#  (('bitcoin', 'cryptocurrencies'), 1),
#  (('cryptocurrencies', 'might'), 1),
#  (('might', 'noticed'), 1)]

# %%
# Generate the Ethereum N-grams where N=2
eth_grams = ngrams(tokenizer(ethereum_df.text.str.cat()), 2)
Counter(eth_grams).most_common(20)
# Out:
# [(('blog', 'post'), 3),
#  (('new', 'blog'), 2),
#  (('post', 'company'), 2),
#  (('according', 'new'), 2),
#  (('charsfeb', 'reuters'), 2),
#  (('charsto', 'believers'), 2),
#  (('believers', 'open'), 2),
#  (('open', 'public'), 2),
#  (('public', 'blockchains'), 2),
#  (('blockchains', 'provide'), 2),
#  (('provide', 'second'), 2),
#  (('second', 'chance'), 2),
#  (('chance', 'building'), 2),
#  (('building', 'digital'), 2),
#  (('digital', 'economy'), 2),
#  (('economy', 'fact'), 2),
#  (('fact', 'application'), 2),
#  (('application', 'built'), 2),
#  (('built', 'top'), 2),
#  (('top', 'blockchains'), 2)]

# %%
# Generate the Ethereum N-grams where N=2
processed_ethereum = ethereum_df['text'][0]
result_ethereum = tokenizer(processed_ethereum)
bigram_counts_ethereum = Counter(ngrams(result_ethereum, n=2))
print(dict(bigram_counts_ethereum))
# Out:
# {('new', 'blog'): 1, ('blog', 'post'): 2, ('post', 'company'): 1, ('company', 'eth'): 1, ('eth', 'bitcoin'): 1, ('bitcoin', 'takenillustration'): 1, ('takenillustration', 'alex'): 1, ('alex', 'castro'): 1, ('castro', 'vergein'): 1, ('vergein', 'blog'): 1, ('post', 'published'): 1, ('published', 'early'): 1, ('early', 'hour'): 1, ('hour', 'thursday'): 1, ('thursday', 'morning'): 1, ('morning', 'cryptocurrency'): 1, ('cryptocurrency', 'char'): 1}

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
listed_text = []

for text in bitcoin_df['text']:
    list_btc = text
    listed_text.append(list_btc)

btc_text = ' '.join(listed_text)

tokenized_btc_text = (tokenizer(btc_text))

print(dict(token_count(tokenized_btc_text, N=10)))
# Out:
# {'char': 20, 'bitcoin': 16, 'ha': 6, 'company': 6, 'open': 5, 'mining': 5, 'el': 4, 'building': 4, 'new': 4, 'last': 3}

# %%
# Use token_count to get the top 10 words for Ethereum
listed_text_eth = []

for text in ethereum_df['text']:
    list_eth = text
    listed_text_eth.append(list_eth)

eth_text = ' '.join(listed_text_eth)

tokenized_eth_text = (tokenizer(eth_text))

print(dict(token_count(tokenized_eth_text, N=10)))
# Out:
# {'char': 19, 'ethereum': 8, 'cryptocurrency': 7, 'new': 6, 'company': 5, 'million': 5, 'platform': 4, 'digital': 4, 'blockchains': 4, 'blog': 3}

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
import nltk
nltk.download('wordnet')
mpl.rcParams['figure.figsize'] = [20.0, 10.0]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lincoln\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Generate the Bitcoin word cloud
wordcloud_btc = ' '.join(tokenized_btc_text)
wc = WordCloud(width=1500, height=900).generate(wordcloud_btc)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show();

# %%
# Generate the Ethereum word cloud
wordcloud_eth = ' '.join(tokenized_eth_text)
wc = WordCloud(width=1500, height=900).generate(wordcloud_eth)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show();

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Run the NER processor on all of the text
doc = nlp(btc_text)
# Add a title to the document
doc.user_data['title'] = 'BTC NER Processor'

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">BTC NER Processor</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with the total value of the market tumbling from a high of $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  tr… [+4782 chars]
# ...

# %%
# List all Entities
print([ent.text for ent in doc.ents])
# Out:
# ['last week', '3', 'El Salvador', 'US', '2021', 'Alex Castro', 'Verge', 'The International Monetary Fund’s', 'El', 'Bitcoin', 'Joe Raedle/Getty Images', 'Square', 'Bitcoin', 'Israeli', 'Tal Prihar', 'Illustration', 'Alex Castro', 'Verge', 'two-year', '4,836', 'ETH', '443', 'Alex Castro', 'Verge', 'the early hours', 'Thursday', 'morning', 'Netflix', 'about one', 'Ilya Lichtenstein', 'this week', 'Saturday', 'more than 50%', 'November', 'more than $', 'Jack Dorsey', 'Twitter', 'first', 'October last year', 'the "Giga Texas', 'Elon Musk', 'Friday', 'Fintech', 'New York City', 'British', 'Richard ODell', 'house', 'October', 'Poulde', 'Russia', 'Thursday', 'Russian', 'the last five years', 'about 25,000', 'Lichtensteins', 'Margaret Lynaugh', 'Bitcoin', 'El Salvador', 'US', 'The International Monetary Fund', 'El Salvador', 'Reuters', 'Jan 26', 'Reuters', 'The U.S. Securities and Exchange Commission', 'Thursday', 'ETF', 'Fidelitys Wise Origin Bitcoin', '+202', 'Sundays Super Bowl', 'Larry D
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Run the NER processor on all of the text
doc_eth = nlp(eth_text)

# Add a title to the document
doc_eth.user_data['title'] = 'ETH NER Processor'

# %%
# Render the visualization
displacy.render(doc_eth, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">ETH NER Processor</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
# ...

# %%
# List all Entities
print([ent.text for ent in doc_eth.ents])
# Out:
# ['4,836', 'ETH', '443', 'Alex Castro', 'Verge', 'the early hours', 'Thursday', 'morning', 'roughly $15 million', 'Crypto.com', 'Tornado Cash', 'Fintech', 'New York City', 'September', 'Robinhood', 'Crypto.com', 'about $34 million', 'Monday', 'Ethereum', 'Vitalik Buterin', 'Ethereum', 'Feb 7', 'Reuters', 'Monday', '$450 million', 'Sequoia Capital India', 'OPEN', 'second', 'OPEN', 'second', 'nearly $324 million', 'Getty Images', 'more than $324 million', 'Wormhole', '120,000', 'wEth', 'Ethereum', 'nearly $324 million', 'Getty Images', 'more than $324 million', 'Wormhole', 'Bloomberg TV', 'Crypto.com', 'Kris Marszalek', '400', 'British', 'Richard ODell', 'house', 'October', 'Poulde', 'Feb 4', 'Reuters', '8.82%', '40,611.4', '2202', 'Friday', '3,291.29', 'Bitcoin', '23.2%', 'TIME', 'weekly', 'Vita']

# %% [markdown]
# ---
